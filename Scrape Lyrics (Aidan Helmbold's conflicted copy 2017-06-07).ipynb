# %%
import pandas as pd
import csv

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
artists = { 'beatles'      : 'http://www.lyrics.com/artist/The%20Beatles/3644',
        'taylor_swift' : 'http://www.lyrics.com/artist/Taylor%20Swift/816977',
        'blink182'     : 'http://www.lyrics.com/artist/blink-182/211247',
        'foo_fighters' : 'http://www.lyrics.com/artist/Foo%20Fighters/144725',
        'pearl_jam'    : 'http://www.lyrics.com/artist/Pearl%20Jam/5118'
      }

# %%
def find_lyrics(song_url, browser):
    browser.get(song_url)
    lyric = BeautifulSoup(chrome.find_element_by_id('lyric-body-text').get_attribute('innerHTML'), 'html.parser')
    return lyric.text

# %%
chrome = webdriver.Chrome()

for file_csv, url in artists.items():
    
    file_csv = file_csv + '.csv'
    try:    
        reader = csv.reader(open(file_csv, mode='r'))
        reader.next()
        lyrics = {rows[0]:rows[1] for rows in reader}
    except: 
        lyrics = {}
    chrome.get(url)
    soup = BeautifulSoup(chrome.page_source, 'html.parser')

    for album in soup.find_all('table',{'class':'tdata'}):
        for song in album.find_all('a', href=True):
            if song.text not in lyrics:
                print (song.text)
                song_url = 'http://www.lyrics.com/' + song['href']
                try:
                    lyrics[song.text] = find_lyrics(song_url, chrome)
                except:
                    pass     
    save_lyrics = pd.DataFrame([[k, v] for k, v in lyrics.items()], columns=['Song', 'Lyrics'])
    save_lyrics.set_index('Song', inplace=True)
    save_lyrics[1:].to_csv(file_csv)

chrome.quit()
# Out:
# Ya, Ya
# Here There And Everywhere
# Oh Darling
# Can't Buy Me Love [Live 1965]
# Chains [Stereo][*]
# I'll Be Back [Stereo][*]
# Please Mister Postman [Stereo][*]
# All Things Must Pass [Rehearsal Session]
# Dig a Pony [Rehearsal Session Fragments]
# Dig It [Rehearsal Session]
# Don't Let Me Down [Fragment]
# Get Back [Aka No Pakistanis]
# I've Got a Feeling [Rehearsal Session]
# Let It Be [Rehearsal Session]
# Maxwell's Silver Hammer [Rehearsal Session]
# She Came in Through the Bathroom Window [Rehearsal Session]
# Short Fat Fannie
# Stand by Me
# Three Cool Cats
# Two of Us [Rehearsal Session]
# Woman
# All You Need Is Love [Take 58 - Live Television Broadcast][Live]
# Paperback Writer [Take 1, 2]
# Rain [Take Unknown]
# Anna (Go to Him)
# Ask Me Why
# Baby It's You
# Boys
# Chains
# Do You Want to Know a Secret
# I Saw Her Standing There
# Love Me Do
# Misery
# P.S. I Love You
# Please Please Me
# A Taste of Honey
# There's a Place
# I'll Cry Instead
# Tell Me Why
# And I Love Her [Vocal Version]
# Can't Buy Me Love [Vocal Version]
# I Should Have Known Better [Vocal Version]
# Tell Me Why [Vocal Version]
# Nobody's Child
# Tony Sheridan
# Why
# Tony Sheridan
